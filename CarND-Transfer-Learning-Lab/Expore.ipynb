# %%
import pickle

# %%
with open('./data/vgg_cifar10_100_bottleneck_features_train.p', 'rb') as f:
    train = pickle.load(f)

# %%
type(train)
# Out:
# dict

# %%
train.keys()
# Out:
# dict_keys(['features', 'labels'])

# %%
type(train['features'])
# Out:
# numpy.ndarray

# %%
train['features'][0]
# Out:
# array([[[  3.83482027e+00,   0.00000000e+00,   9.21114802e-01,
#            1.93552804e+00,   0.00000000e+00,   6.63010180e-01,
#            1.15986693e+00,   2.47270203e+00,   2.07353783e+00,
#            1.19035101e+00,   6.59685612e+00,   2.70670086e-01,
#            3.57333302e+00,   1.95524842e-01,   0.00000000e+00,
#            2.60450155e-01,   0.00000000e+00,   1.64117157e-01,
#            1.73381418e-02,   1.18367836e-01,   1.13679969e+00,
#            2.81948298e-01,   9.10271645e-01,   8.96595383e+00,
#            2.41686487e+00,   0.00000000e+00,   3.75203848e+00,
#            8.68028462e-01,   0.00000000e+00,   2.56789941e-02,
#            1.17743025e-02,   3.81638503e+00,   1.31229115e+00,
#            1.94805861e+00,   4.77097213e-01,   0.00000000e+00,
#            2.65260196e+00,   9.46560144e-01,   1.66613683e-01,
#            1.52895820e+00,   7.98244178e-01,   1.64050199e-02,
#            2.55368263e-01,   0.00000000e+00,   7.48018742e-01,
# ...
